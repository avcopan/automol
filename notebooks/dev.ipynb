# %%
from automol import Identity, Geometry

ident = Identity(kind="stereoisomer", algorithm="rdkit smiles", value="CC[CH]C")
geo = Geometry.from_xyz_file(
    "/home/tns97255/coding/autodev/automol/tests/data/propyl_oxirane.xyz",
    charge=0,
    spin=1,
)
Identity.from_geometry(geo, algorithm="rdkit smiles")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/coding/autodev/automol/src/automol/geom.py:149, in Geometry.rdkit_mol(self)
#     148 try:
# --> 149     rdDetermineBonds.DetermineBondOrders(
#     150         trial_mol, charge=trial_charge, allowChargedFragments=True
#     151     )
#     152 except ValueError as err:
#
# ValueError: Final molecular charge (0) does not match input (-1); could not find valid bond ordering
#
# The above exception was the direct cause of the following exception:
#
# GeometryConversionError                   Traceback (most recent call last)
# Cell In[12], line 9
#       5     "/home/tns97255/coding/autodev/automol/tests/data/propyl_oxirane.xyz",
#       6     charge=0,
#       7     spin=0,
#       8 )
# ----> 9 Identity.from_geometry(geo, algorithm="rdkit smiles")
#
# ...
