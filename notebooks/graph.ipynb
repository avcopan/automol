# %%
from automol import Geometry, geom, Identity, Algorithm
from IPython.display import display

smiles = "CC"

geo1 = Identity.from_value(smiles, algorithm=Algorithm.RDKIT_SMILES).geometry()
geo2 = Identity.from_value(smiles, algorithm=Algorithm.RDKIT_SMILES).geometry()
# Out:
# <div id="3dmolviewer_17842469467023137"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17842469467023137" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17842469467023137 = null;
# var warn = document.getElementById("3dmolwarning_17842469467023137");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17842469467023137 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17842469467023137"),{backgroundColor:"white"});
# viewer_17842469467023137.zoomTo();
# 	viewer_17842469467023137.addModel("8\nGeometry(q=0, s=0)\nC     -0.75987677  -0.00451380  -0.05133404\nC      0.73787390  -0.03469719   0.00539877\nH     -1.12886158  -0.18390449   0.98188894\nH     -1.07290728   1.01948937  -0.32350951\nH     -1.20091127  -0.78792311  -0.67860822\nH      1.05317167   0.89768102   0.54027793\nH      1.22046265   0.02409412  -0.98008323\nH      1.15104868  -0.93022593   0.50596937","xyz");
# 	viewer_17842469467023137.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17842469467023137.addLabel(0,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 0});
# 	viewer_17842469467023137.addLabel(1,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 1});
# 	viewer_17842469467023137.addLabel(2,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 2});
# 	viewer_17842469467023137.addLabel(3,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 3});
# 	viewer_17842469467023137.addLabel(4,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 4});
# 	viewer_17842469467023137.addLabel(5,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 5});
# 	viewer_17842469467023137.addLabel(6,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 6});
# 	viewer_17842469467023137.addLabel(7,{"backgroundOpacity": 0.0, "fontColor": "black", "alignment": "center", "inFront": true},{"index": 7});
# viewer_17842469467023137.render();
# });
# </script>
# 8
# Geometry(q=0, s=0)
# C     -0.75987677  -0.00451380  -0.05133404
# C      0.73787390  -0.03469719   0.00539877
# H     -1.12886158  -0.18390449   0.98188894
# H     -1.07290728   1.01948937  -0.32350951
# H     -1.20091127  -0.78792311  -0.67860822
# H      1.05317167   0.89768102   0.54027793
# H      1.22046265   0.02409412  -0.98008323
# H      1.15104868  -0.93022593   0.50596937
